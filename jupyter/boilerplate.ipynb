# %% [markdown]
# # Q-ETL Development Notebook
#
# This notebook allows you to create processing jobs with the QGIS ETL framework from a Jupyter notebook.

# %% [markdown]
# ## Setup and Initialize
#
# Don't change anything here, unless the project root to Q_ETL

# %%
import os
import sys

# Setup paths (adjust project_root to your installation)
project_root = r'C:\App\Github\QGIS_ETL' ## CHANGE THIS TO MATCH YOUR INSTALLATION
os.chdir(project_root)
sys.argv[0] = os.path.join(project_root, 'python', 'dummy.py')
sys.path.insert(0, os.path.join(project_root, 'python'))

# Import Q-ETL (QGIS initialization happens automatically in core/__init__.py)
from core import *
from engine import *

print(f"✓ QGIS initialized (version {qgs.applicationVersion()})")
print(f"✓ Working directory: {os.getcwd()}")
# Out:
# 2026-02-11 15:46:26 - INFO - start_logfile : ##################################################
# 2026-02-11 15:46:26 - INFO - start_logfile : Q-ETL JOB LOG
# 2026-02-11 15:46:26 - INFO - start_logfile : JOB: C:\App\Github\QGIS_ETL\python\dummy.py
# 2026-02-11 15:46:26 - INFO - start_logfile : STARTTIME: 11/02/2026, 15:46
# 2026-02-11 15:46:26 - INFO - start_logfile : ##################################################
# 2026-02-11 15:46:26 - INFO - start_logfile :
# 2026-02-11 15:46:27 - INFO - initdb : Using internal DB C:\App\Github\QGIS_ETL/db/internal.db
# 2026-02-11 15:46:27 - INFO - get_bin_folder : QGIS installed in OSGeo4W bundle
# 2026-02-11 15:46:27 - INFO - validateEnvironment : Validating Environment and settings
# 2026-02-11 15:46:27 - INFO - validateEnvironment : Qgs_PrefixPath found
# 2026-02-11 15:46:27 - INFO - validateEnvironment : QGIS_Bin_Folder found
# 2026-02-11 15:46:27 - INFO - validateEnvironment : QGIS_ini_Path found
# ...

# %% [markdown]
# ### YOUR CODE AFTER THIS BLOCK...
