# %% [markdown]
# # Q-ETL Development Notebook
#
# This notebook allows you to create processing jobs with the QGIS ETL framework from a Jupyter notebook.

# %% [markdown]
# ## Setup and Initialize
#
# Don't change anything here, unless the project root to Q_ETL

# %%
import os
import sys

# Setup paths (adjust project_root to your installation)
project_root = r'C:\github\Q-ETL' ## CHANGE THIS TO MATCH YOUR INSTALLATION
os.chdir(project_root)
sys.argv[0] = os.path.join(project_root, 'python', 'dummy.py')
sys.path.insert(0, os.path.join(project_root, 'python'))

# Import Q-ETL (QGIS initialization happens automatically in core/__init__.py)
from core import *
from engine import *

print(f"✓ QGIS initialized (version {qgs.applicationVersion()})")
print(f"✓ Working directory: {os.getcwd()}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       4 # Setup paths (adjust project_root to your installation)
#       5 project_root = r'C:\App\Github\QGIS_ETL' ## CHANGE THIS TO MATCH YOUR INSTALLATION
# ----> 6 os.chdir(project_root)
#       7 sys.argv[0] = os.path.join(project_root, 'python', 'dummy.py')
#       8 sys.path.insert(0, os.path.join(project_root, 'python'))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\App\\Github\\QGIS_ETL'

# %% [markdown]
# ### YOUR CODE AFTER THIS BLOCK...
